# %% [markdown]
# ## Use Of Describe() Method

# %%
import pandas as pd

data = {
    "Name": ["Ahmed", "Fatima", "Hassan", "Ayesha", "Bilal", "Zainab", "Umar", "Maryam"],
    "Age": [28, 34, 22, 30, 29, 40, 25, 32],
    "Salary": [50000, 60000, 45000, 52000, 49000, 70000, 48000, 50000],
    "Performance Score": [85, 90, 78, 92, 88, 95, 80, 89]
}

df = pd.DataFrame(data)
print(f'Sample Data Frame\n {df}')
# Out:
# Sample Data Frame
#       Name  Age  Salary  Performance Score
# 0   Ahmed   28   50000                 85
# 1  Fatima   34   60000                 90
# 2  Hassan   22   45000                 78
# 3  Ayesha   30   52000                 92
# 4   Bilal   29   49000                 88
# 5  Zainab   40   70000                 95
# 6    Umar   25   48000                 80
# 7  Maryam   32   50000                 89

# %%
print('Descriptive Statistics of Df')
print(df.describe())
# Out:
# Descriptive Statistics of Df
#              Age        Salary  Performance Score
# count   8.000000      8.000000           8.000000
# mean   30.000000  53000.000000          87.125000
# std     5.529144   8124.038405           5.817154
# min    22.000000  45000.000000          78.000000
# 25%    27.250000  48750.000000          83.750000
# 50%    29.500000  50000.000000          88.500000
# 75%    32.500000  54000.000000          90.500000
# max    40.000000  70000.000000          95.000000
