# %% [markdown]
# ## Scikit Learn Basic Usage

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
from sklearn.linear_model import LinearRegression

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Create a regression line plot
sns.lmplot(x='total_bill',y='tip', data=df)
# Show the plot
plt.show()

# %%
# Select the feature Column from df
X = df[['total_bill']]
# Select the Label from df
y = df['tip']

# %%
# Load the linear regression model 
model = LinearRegression()
# fit the model means train the model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
#let Predicts the tip for an unknown bill
model.predict([[45]])
# Out:
# c:\Users\Abdul Rehman\Desktop\Machine Learning\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.6463729])

# %%
# 1-import the libraries
# 2-import pandas as pd
# 3-import matplotlib.pyplot as plt
# 4-load the dataset
# 5-df = sns.load_dataset('tips')
# 6-select the feature Column from df
# 7-X = df[['total_bill']]
# 8-select the Label from df
# 9-y = df['tip']
# 10-load the linear regression model
# 11-model = LinearRegression()
# 12-fit the model means train the model
# 13-model.fit(X,y)
# 14-let Predicts the tip for an unknown bill
# 15-model.predict([[45]])
