# %% [markdown]
# ## Detecting Missing Values

# %%
# Missing Data is what?
'''
1-NaN (not a number)
2-None (for object data types)
'''
# How to Detect Missing Data
'''
1-Before Handling the data u need to know where data is missing for this we use:
    isnull() return:
      True: mean NaN (Value is Missing)
      False: if false mean value is present
'''
# Out:
# '\n1-Before Handling the data u need to know where data is missing for this we use:\n    isnull() return:\n      True: mean NaN (Value is Missing)\n      False: if false mean value is present\n'

# %%
import pandas as pd

data = {
    "Name": ["Ahmed", None, "Hassan", "Ayesha", "Bilal", "Zainab", "Umar", "Maryam"],
    "Age": [28, None, 22, 30, 29, 40, 25, 32],
    "Salary": [50000, None, 45000, 52000, 49000, 70000, 48000, 50000],
    "Performance Score": [85, None, 78, 92, 88, 95, 80, 89]
}

df = pd.DataFrame(data)
print(f'Sample Data Frame\n {df}')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       3 data = {
#       4     "Name": ["Ahmed", None, "Hassan", "Ayesha", "Bilal", "Zainab", "Umar", "Maryam"],
#       5     "Age": [28, None, 22, 30, 29, 40, 25, 32],
#       6     "Salary": [50000, None, 45000, 52000, 49000, 70000, 48000, 50000],
#       7     "Performance Score": [85, None, 78, 92, 88, 95, 80, 89]
#       8 }
#      10 df = pd.DataFrame(data)
#
# File c:\Users\Abdul Rehman\Desktop\AI & ML\venv\Lib\site-packages\pandas\__init__.py:31
#      28         _missing_dependencies.append(f"{_dependency}: {_e}")
#      30 if _missing_dependencies:  # pragma: no cover
# ---> 31     raise ImportError(
#      32         "Unable to import required dependencies:\n" + "\n".join(_missing_dependencies)
#      33     )
# ...

# %%
print(df.isnull())
# Out:
#     Name    Age  Salary  Performance Score
# 0  False  False   False              False
# 1   True   True    True               True
# 2  False  False   False              False
# 3  False  False   False              False
# 4  False  False   False              False
# 5  False  False   False              False
# 6  False  False   False              False
# 7  False  False   False              False

# %%
# if u also want to check how much value is missing
print(df.isnull().sum())
# Out:
# Name                 1
# Age                  1
# Salary               1
# Performance Score    1
# dtype: int64

# %%
#Key Points:
'''
Check the percetnage of missing data
- df.isnull().mean() * 100
'''
