# %%
# Data Preprocessing Steps 
'''
1-Data Cleaning: 
-Handling missing values
-removing duplicates 
-removing outliers
-smoothing noisy data 
-remvoing inconsistencies
-correcting errors.

2-Data Integration: 
-Data Integration: Combining data from different sources into a coherent dataset.
-Data Duplication: Identifying duplicate records.
-Data Merging: Combining datasets.
-Data Consolidation: Summarizing data from multiple sources.

3-Data Transformation: Normalizing or scaling data, encoding categorical variables.
4-Data Reduction: Reducing the volume of data while maintaining its integrity, such as through dimensionality reduction techniques.
    -Dimensonality Reduction Techniques: PCA, t-SNE, LDA
    -Numerosity Reduction Techniques: Sampling, Aggregation
    -Data Compression: Lossless (ZIP, PNG), Lossy (JPEG, MP3)
5-Data Discretization: Converting continuous data into discrete bins or intervals.
'''
