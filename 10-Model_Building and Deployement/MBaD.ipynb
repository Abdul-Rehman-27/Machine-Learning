# %%
#Model Building
# 1-Define Problem 
# 2-Data Collection / Prepare Data / Data Gathering
'''
-Quality
-Data 
If u don't have your own data then u can also use the secondary (written by someone else) data
'''
# 3-Data Preprocessing
'''
-Raw Data 
-Explore That Raw Data
-Then Remove Outliers, Anomlies, Missing Values, Feature Engineering
-This above steps is called Data Wrangling or Data Pre Processing'''

# 4-Choose a Model 
'''
-Check the datatype 
-Based on the datatype choose either classification or regression or any other model'''

# 5-Split the Data
'''
-Some part of data is used for training 
-Some part of data is used for testing'''

# 6-Evaluating the Model

# 7-Hyperparameter / Fine Tuning

# 8-k fold cross validation
'''
- What it is:
K-fold cross validation is a technique to evaluate the performance of a machine learning model. 
The data is split into 'k' equally sized folds. The model is trained on k-1 folds and tested on the remaining fold. 
This process is repeated k times, each time with a different fold as the test set. 
The final performance metric is the average of the k test results, providing a more robust estimate of model accuracy.
'''

# 9-Model Finalization 
'''
-Test on different Datasets
-If its perofrms good enough then'''

# 10-Deploy the Model 
'''
-Hosting 
-ML Ooperations (MLOps)'''

# 11-Reset, Update, Monitor and then Update the Model
