# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('house_prices.csv')
print("Data Set\n",df)
# Out:
# Data Set:
#     Size  Bedrooms  Age   Price
# 0  1000         2   10  150000
# 1  1500         3    5  200000
# 2  2000         3   20  180000
# 3  2500         4    8  250000
# 4  3000         4    2  310000
# 5  1800         3   15  175000
# 6  2200         3    7  230000
# 7  2700         4   12  260000
# 8  3200         5    4  330000
# 9  3500         5    1  370000

# %%
# Load dataset
df = pd.read_csv("house_prices.csv")

# Features and Target
X = df[['Size','Bedrooms']]
y = df['Price']

# Train Model
model = LinearRegression()
model.fit(X, y)

# User Input
size = int(input("Enter size of house in square feet: "))
bedrooms = int(input("Enter number of bedrooms: "))

# Prediction
predictions = model.predict([[size, bedrooms]])
print("Predicted Price:", np.round(predictions[0]))
# Out:
# Predicted Price: 348891.0
# c:\Users\Abdul Rehman\Desktop\Machine Learning\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
